# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
import time
import random
import pandas as pd

# %%
# driver = webdriver.Chrome(executable_path='/home/amit/Documents/ITC/COURSE/NOTEBOOKS/SCRAPING/chromedriver_linux64/chromedriver')

# %%
driver = webdriver.Chrome(executable_path='chromedriver_linux64/chromedriver')

# %%
driver.get("https://www.glassdoor.com/Job/jobs.htm?suggestCount=0&suggestChosen=false&clickSource=searchBtn&typedKeyword=&sc.keyword=&locT=N&locId=119&jobType=")

# %%
links = []

# %%
while True:
    job_headers = driver.find_elements_by_class_name('jobHeader')
    for job in job_headers:
        links.append(job.find_element_by_css_selector('a').get_attribute('href'))
    try:
        driver.find_element_by_class_name('next').find_element_by_css_selector('a').click()
        time.sleep(random.randint(2,4))
    except Exception as error:
        break       
    try:
        driver.find_element_by_id("prefix__icon-close-1").click()
    except NoSuchElementException:
        pass

# %%
# len(links)

# %%
#driver.get(links[-2])

# %%
#company = driver.find_element_by_class_name('strong.ib').text
# Out:
# 'SQlink'

# %%
# location = driver.find_element_by_class_name('subtle.ib').text[3:]

# %%
# location
# Out:
# 'Israel'

# %%
# desc = driver.find_element_by_class_name('desc.css-58vpdc.ecgq1xb3').text.replace('\n', ' ')

# %%
# desc
# Out:
# 'תיאור המשרה: לחברת ליסינג ישראלית פרטית המובילה באזור המרכז ועוסקת בתחום השכרה ומכירת רכב דרוש\\ה תומכ\\ת טכני מנוסה להשתלב בצוות מוביל, עם הזמדנות למידה והתפתחות מהשורה הראשונה. תנאים מעולים למתאימים!  דרישות המשרה: ניסיון בתמיכה טלפונית ניסיון בטיפול במחשבי pc - חומרה ותוכנה ידע ביישומי office (בעיקר outlook) גמישות בשעות העבודה לרבות עבודה בסופ"ש ובחגים (סבב כוננים) רישיון נהיגה ידע בעבודה מול שרתי טרמינל CITRIX ידע ברשתות ותשתיות תקשורת ניסיון בטיפול במערך טלפוניה  מס\' משרה: 94474'

# %%
# more = driver.find_elements_by_class_name("value")

# %%
# fields = driver.find_elements_by_xpath("//label[@for='InfoFields']")
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="b5f5618dc86be15eabb23c06ef21ec85", element="cc26a69f-1255-422d-bffc-e8450cf285b0")>

# %%
# Headquarters = 0
# Type = 1
# Sector = 2
# Size = 3
# Industry = 4
# Revenue = 5

# %%
# driver.find_elements_by_xpath("//label[@for='InfoFields']")[1].find_element_by_xpath("//span[@class='value']").text
# Out:
# 'Yoqne‘am ‘Illit, Israel'

# %%
glassdoor_jobs = pd.DataFrame()

# %%
for i,link in enumerate(links):  
    driver.get(link)
    time.sleep(random.randint(2,4))
    try:
        driver.find_element_by_id("prefix__icon-close-1").click()
    except NoSuchElementException:
        pass
    try:
        glassdoor_jobs.loc[i, 'title'] = driver.find_element_by_class_name('mt-0.margBotXs.strong').text
    except NoSuchElementException:
        driver.get(link)
        glassdoor_jobs.loc[i, 'title'] = driver.find_element_by_class_name('mt-0.margBotXs.strong').text
    glassdoor_jobs.loc[i, 'company'] = driver.find_element_by_class_name('strong.ib').text
    glassdoor_jobs.loc[i, 'location'] = driver.find_element_by_class_name('subtle.ib').text[3:]
    glassdoor_jobs.loc[i, 'desc'] = driver.find_element_by_class_name('desc.css-58vpdc.ecgq1xb3').text.replace('\n', ' ')
    try:
        driver.find_element_by_xpath("//span[@class='link' and text()='Company']").click()
    except NoSuchElementException:
        pass
    time.sleep(random.randint(2,4))
    fields = driver.find_elements_by_xpath("//label[@for='InfoFields']")
    values = driver.find_elements_by_class_name("value")
    for field in zip(fields,values):
        field_name = field[0].text
        field_value = field[1].text
        glassdoor_jobs.loc[i, field_name] = field_value
#     if i == 3:
#         break

# %%
glassdoor_jobs_old_1 = glassdoor_jobs

# %%
glassdoor_jobs
# Out:
#                                                  title  \
# 0                                     C#.net Developer
# 1                                                   QA
# 2                           Product Manager | Big Data
# 3                            מנהל /ת קבוצת הנדסה לצפון
# 4                                                 HRBP
# 5                                   Frontend Developer
# 6                           mechanical design engineer
# 7                                      Devops Engineer
# 8                                                 HRBP
# 9                                      Devops Engineer
# 10                                      NOC Technician
# 11                               Senior Java Developer
# 12                          Embedded Software Engineer
# 13                         Marketing Automation Expert
# 14   Want to work in high-tech? Software Developmen...
# 15                                       C++ Developer
# ...

# %%
glassdoor_jobs.to_excel("glassdoor_jobs.xlsx")

# %%
#  more = driver.find_elements_by_class_name("value")
#     try:
#         glassdoor_jobs.loc[i, 'Headquarters'] = more[Headquarters].text
#         glassdoor_jobs.loc[i, 'Type'] = more[Type].text
#         glassdoor_jobs.loc[i, 'Sector'] = more[Sector].text
#         glassdoor_jobs.loc[i, 'Size'] = more[Size].text
#         glassdoor_jobs.loc[i, 'Industry'] = more[Industry].text
#         glassdoor_jobs.loc[i, 'Revenue'] = more[Revenue].text

# %%
# for link in links:

# %%
# try: 
#     driver.find_element_by_class_name('neext').find_element_by_css_selector('a').click()
# except Exception as error:
#     print("yay")
#     print(error)

# %%
# error

# %%
# for job in job_headers:
#     links.append(job.find_element_by_css_selector('a').get_attribute('href'))

# %%
# links

# %%
# driver.get(link)

# %%
# driver.find_element_by_xpath("//span[@class='link' and text()='Company']").click()

# %%
# driver.find_element_by_xpath("//span[@class='link' and text()='Job']").click()
